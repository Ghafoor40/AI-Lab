# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r"C:\Users\Windows 10\OneDrive\Desktop\ai lab task\tested.csv")

# %% [markdown]
# Data Pre-Processing

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Name      418 non-null    object
#  3   Sex       418 non-null    object
#  4   Age       418 non-null    int64
#  5   SibSp     418 non-null    int64
#  6   Parch     418 non-null    int64
#  7   Ticket    418 non-null    object
#  8   Fare      417 non-null    float64
#  9   Cabin     91 non-null     object
#  10  Embarked  418 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 36.1+ KB

# %%
dataset.shape
# Out:
# (418, 11)

# %%
print("We have {} rows.".format(dataset.shape[0]))
print("We have {} columns.".format(dataset.shape[1]))
# Out:
# We have 418 rows.
# We have 12 columns.

# %%
print("\nNull Values:")
print(np.sum(pd.isnull(dataset)))
# Out:
# Null Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# c:\Users\Windows 10\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print("\nUnique values in Sex column:")
print(dataset['Sex'].unique())
# Out:
# Unique values in Sex column:
# ['male' 'female']

# %%
mode_value = dataset['Age'].mode()[0]
dataset['Age'] = dataset['Age'].fillna(mode_value)

# %%
dataset['Age'] = dataset['Age'].astype(np.int64)

# %%
if 'PassengerId' in dataset.columns:
    dataset.drop('PassengerId', axis=1, inplace=True)

# %% [markdown]
# Changing Datatypes of Columns to be "Int"

# %%
print("\nDatatypes:")
print(dataset.dtypes)
# Out:
# Datatypes:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age           int64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
X = dataset.iloc[:, 0:-1]
y = dataset.iloc[:, -1]

# %%
print("\nX shape:", X.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (418, 10)
# Y shape: (418,)

# %%
cat_columns = X.select_dtypes(include=['object']).columns
X[cat_columns] = X[cat_columns].apply(lambda col: pd.factorize(col)[0])

# %%
print("\nAfter Encoding:")
print(X.head())
# Out:
# After Encoding:
#    Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket     Fare  Cabin
# 0         0       3     0    0   34      0      0       0   7.8292     -1
# 1         1       3     1    1   47      1      0       1   7.0000     -1
# 2         0       2     2    0   62      0      0       2   9.6875     -1
# 3         0       3     3    0   27      0      0       3   8.6625     -1
# 4         1       3     4    1   22      1      1       4  12.2875     -1
